# %% [markdown]
# # [Deep Learning](https://www.cc.gatech.edu/~hays/compvision/proj6/)

# %% [markdown]
# ## Setup

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import cv2
import numpy as np
import random
import torch.nn as nn
import torch.optim as optim
import os.path as osp
import matplotlib.pyplot as plt
from utils import *
import student_code as sc
from torchvision.models import alexnet

data_path = osp.join('../data', '15SceneData')
num_classes = 15

# If you have a good Nvidia GPU with an appropriate environment, 
# try setting the use_GPU flag to True (the environment provided does
# not support GPUs and we will not provide any support for GPU
# computation in this project). Please note that 
# we will evaluate your implementations only using CPU mode so even if
# you use a GPU, make sure your code runs in the CPU mode with the
# environment we provided. 
use_GPU = False
if use_GPU:
    from utils_gpu import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# To train a network in PyTorch, we need 4 components:
# 1. **Dataset** - an object which can load the data and labels given an index.
# 2. **Model** - an object that contains the network architecture definition.
# 3. **Loss function** - a function that measures how far the network output is from the ground truth label.
# 4. **Optimizer** - an object that optimizes the network parameters to reduce the loss value.

# %% [markdown]
# This project has two main parts. In Part 1, you will train a deep network from scratch. In Part 2, you will "fine-tune" a trained network.

# %% [markdown]
# ## Part 0. Warm up! Training a Deep Network from Scratch

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# You do not need to code anything for this part. You will simply run the code we provided, but we want you to report the result you got. This section will also familiarize you with the steps of training a deep network from scratch.

# %%
# Training parameters.
input_size = (64, 64)
RGB = False  
base_lr = 1e-2  # may try a smaller lr if not using batch norm
weight_decay = 5e-4
momentum = 0.9

# %% [markdown]
# We will first create our datasets, by calling the create_datasets function from student_code. This function returns a separate dataset loader for each split of the dataset (training and testing/validation). Each dataloader is used to load the datasets after appling some pre-processing transforms. In Part 1, you will be asked to add a few more pre-processing transforms to the dataloaders by modifying this function.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now we will create our network model using the SimpleNet class from student_code. The implementation provided in the SimpleNet class gives you a basic network. In Part 1, you will be asked to add a few more layers to this network.

# %%
# Create the network model.
model = sc.SimpleNet(num_classes=num_classes, rgb=False, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): MaxPool2d(kernel_size=5, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (3): ReLU()
#     (4): Dropout(p=0.5)
#     (5): Conv2d(10, 15, kernel_size=(5, 5), stride=(1, 1), bias=False)
#     (6): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): ReLU()
#     (9): Dropout(p=0.5)
#   )
#   (classifier): Conv2d(15, 15, kernel_size=(6, 6), stride=(1, 1))
# )

# %% [markdown]
# Next we will create the loss function and the optimizer.

# %%
# Create the loss function.
# see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
loss_function = nn.CrossEntropyLoss()

# %%
# Create the optimizer and a learning rate scheduler
optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
# Currently a simple step scheduler.
# See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
# and how to use them
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

# %% [markdown]
# Finally we are ready to train our network! We will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# train the network!
params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part1
# resume_optim: True
# experiment: part1
# val_freq: 1
# checkpoint_file: None
# num_workers: 4
# print_freq: 100
# shuffle: True
# batch_size: 50
# do_val: True
# n_epochs: 100
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 2.648, top-1 accuracy 18.000, top-5 accuracy 52.000
# train part1: loss 2.664706
# val part1: batch 0/59, loss 3.037, top-1 accuracy 0.000, top-5 accuracy 0.000
# val part1: loss 2.634302
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 2.653, top-1 accuracy 16.000, top-5 accuracy 42.000
# train part1: loss 2.570846
# val part1: batch 0/59, loss 3.143, top-1 accuracy 0.000, top-5 accuracy 0.000
# val part1: loss 2.552107
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 2.500, top-1 accuracy 14.000, top-5 accuracy 50.000
# train part1: loss 2.485453
# val part1: batch 0/59, loss 2.198, top-1 accuracy 18.000, top-5 accuracy 96.000
# val part1: loss 2.513337
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 2.401, top-1 accuracy 22.000, top-5 accuracy 72.000
# train part1: loss 2.370460
# val part1: batch 0/59, loss 3.099, top-1 accuracy 0.000, top-5 accuracy 6.000
# val part1: loss 2.378228
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 2.290, top-1 accuracy 30.000, top-5 accuracy 68.000
# train part1: loss 2.234845
# val part1: batch 0/59, loss 2.142, top-1 accuracy 42.000, top-5 accuracy 82.000
# val part1: loss 2.272883
# Checkpoint saved
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 2.133, top-1 accuracy 20.000, top-5 accuracy 70.000
# train part1: loss 2.158323
# val part1: batch 0/59, loss 2.638, top-1 accuracy 14.000, top-5 accuracy 52.000
# val part1: loss 2.293269
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 2.207, top-1 accuracy 32.000, top-5 accuracy 78.000
# train part1: loss 2.126224
# val part1: batch 0/59, loss 2.144, top-1 accuracy 20.000, top-5 accuracy 82.000
# val part1: loss 2.356525
# Checkpoint saved
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 2.171, top-1 accuracy 30.000, top-5 accuracy 76.000
# train part1: loss 2.081253
# val part1: batch 0/59, loss 3.023, top-1 accuracy 0.000, top-5 accuracy 40.000
# val part1: loss 2.211569
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 2.093, top-1 accuracy 30.000, top-5 accuracy 74.000
# train part1: loss 2.009198
# val part1: batch 0/59, loss 3.328, top-1 accuracy 4.000, top-5 accuracy 32.000
# val part1: loss 2.185072
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 2.050, top-1 accuracy 28.000, top-5 accuracy 76.000
# train part1: loss 1.991949
# val part1: batch 0/59, loss 2.706, top-1 accuracy 14.000, top-5 accuracy 54.000
# val part1: loss 2.210808
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 1.889, top-1 accuracy 40.000, top-5 accuracy 78.000
# train part1: loss 1.930401
# val part1: batch 0/59, loss 2.502, top-1 accuracy 24.000, top-5 accuracy 64.000
# val part1: loss 2.199508
# Checkpoint saved
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 1.914, top-1 accuracy 46.000, top-5 accuracy 86.000
# train part1: loss 1.924105
# val part1: batch 0/59, loss 2.179, top-1 accuracy 34.000, top-5 accuracy 70.000
# val part1: loss 2.188606
# Checkpoint saved
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 1.897, top-1 accuracy 36.000, top-5 accuracy 78.000
# train part1: loss 1.829307
# val part1: batch 0/59, loss 2.884, top-1 accuracy 10.000, top-5 accuracy 50.000
# val part1: loss 2.156922
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 1.656, top-1 accuracy 50.000, top-5 accuracy 86.000
# train part1: loss 1.814532
# val part1: batch 0/59, loss 2.721, top-1 accuracy 14.000, top-5 accuracy 54.000
# val part1: loss 2.200127
# Checkpoint saved
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 1.742, top-1 accuracy 50.000, top-5 accuracy 82.000
# train part1: loss 1.791029
# val part1: batch 0/59, loss 2.784, top-1 accuracy 18.000, top-5 accuracy 52.000
# val part1: loss 2.122443
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 1.543, top-1 accuracy 48.000, top-5 accuracy 84.000
# train part1: loss 1.647354
# val part1: batch 0/59, loss 2.807, top-1 accuracy 28.000, top-5 accuracy 48.000
# val part1: loss 2.043284
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 1.508, top-1 accuracy 58.000, top-5 accuracy 84.000
# train part1: loss 1.571854
# val part1: batch 0/59, loss 2.766, top-1 accuracy 16.000, top-5 accuracy 54.000
# val part1: loss 2.128146
# Checkpoint saved
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 1.613, top-1 accuracy 54.000, top-5 accuracy 78.000
# train part1: loss 1.540799
# val part1: batch 0/59, loss 3.577, top-1 accuracy 4.000, top-5 accuracy 36.000
# val part1: loss 2.134239
# Checkpoint saved
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 1.394, top-1 accuracy 56.000, top-5 accuracy 94.000
# train part1: loss 1.536784
# val part1: batch 0/59, loss 1.900, top-1 accuracy 44.000, top-5 accuracy 82.000
# val part1: loss 2.227581
# Checkpoint saved
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 1.490, top-1 accuracy 52.000, top-5 accuracy 92.000
# train part1: loss 1.439697
# val part1: batch 0/59, loss 3.901, top-1 accuracy 6.000, top-5 accuracy 36.000
# val part1: loss 2.140877
# Checkpoint saved
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 1.298, top-1 accuracy 52.000, top-5 accuracy 98.000
# train part1: loss 1.395819
# val part1: batch 0/59, loss 2.439, top-1 accuracy 30.000, top-5 accuracy 72.000
# val part1: loss 2.187421
# Checkpoint saved
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 1.534, top-1 accuracy 52.000, top-5 accuracy 88.000
# train part1: loss 1.383855
# val part1: batch 0/59, loss 3.275, top-1 accuracy 18.000, top-5 accuracy 46.000
# val part1: loss 2.092350
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 1.089, top-1 accuracy 74.000, top-5 accuracy 90.000
# train part1: loss 1.312581
# val part1: batch 0/59, loss 3.149, top-1 accuracy 20.000, top-5 accuracy 46.000
# val part1: loss 2.147712
# Checkpoint saved
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 1.097, top-1 accuracy 72.000, top-5 accuracy 94.000
# train part1: loss 1.315444
# val part1: batch 0/59, loss 2.967, top-1 accuracy 24.000, top-5 accuracy 52.000
# val part1: loss 2.213968
# Checkpoint saved
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 1.231, top-1 accuracy 56.000, top-5 accuracy 90.000
# train part1: loss 1.266427
# val part1: batch 0/59, loss 3.988, top-1 accuracy 16.000, top-5 accuracy 34.000
# val part1: loss 2.125008
# Checkpoint saved
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 1.363, top-1 accuracy 56.000, top-5 accuracy 92.000
# train part1: loss 1.292098
# val part1: batch 0/59, loss 2.435, top-1 accuracy 34.000, top-5 accuracy 74.000
# val part1: loss 2.304756
# Checkpoint saved
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 1.209, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.251564
# val part1: batch 0/59, loss 3.714, top-1 accuracy 16.000, top-5 accuracy 44.000
# val part1: loss 2.209791
# Checkpoint saved
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 1.188, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.154300
# val part1: batch 0/59, loss 3.015, top-1 accuracy 24.000, top-5 accuracy 58.000
# val part1: loss 2.258760
# Checkpoint saved
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 1.071, top-1 accuracy 70.000, top-5 accuracy 98.000
# train part1: loss 1.166939
# val part1: batch 0/59, loss 4.255, top-1 accuracy 12.000, top-5 accuracy 36.000
# val part1: loss 2.225898
# Checkpoint saved
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 1.104, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.071470
# val part1: batch 0/59, loss 3.531, top-1 accuracy 18.000, top-5 accuracy 52.000
# val part1: loss 2.352147
# Checkpoint saved
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 1.062, top-1 accuracy 64.000, top-5 accuracy 100.000
# train part1: loss 1.046037
# val part1: batch 0/59, loss 2.814, top-1 accuracy 28.000, top-5 accuracy 66.000
# val part1: loss 2.416530
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 0.865, top-1 accuracy 72.000, top-5 accuracy 100.000
# train part1: loss 1.064576
# val part1: batch 0/59, loss 4.055, top-1 accuracy 16.000, top-5 accuracy 46.000
# val part1: loss 2.305213
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 1.014, top-1 accuracy 72.000, top-5 accuracy 92.000
# train part1: loss 1.035600
# val part1: batch 0/59, loss 3.275, top-1 accuracy 16.000, top-5 accuracy 54.000
# val part1: loss 2.465159
# Checkpoint saved
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 1.150, top-1 accuracy 62.000, top-5 accuracy 92.000
# train part1: loss 1.034405
# val part1: batch 0/59, loss 3.125, top-1 accuracy 22.000, top-5 accuracy 58.000
# val part1: loss 2.378150
# Checkpoint saved
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 0.995, top-1 accuracy 66.000, top-5 accuracy 98.000
# train part1: loss 0.962430
# val part1: batch 0/59, loss 3.097, top-1 accuracy 28.000, top-5 accuracy 62.000
# val part1: loss 2.447168
# Checkpoint saved
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 0.894, top-1 accuracy 74.000, top-5 accuracy 96.000
# train part1: loss 0.935715
# val part1: batch 0/59, loss 3.776, top-1 accuracy 18.000, top-5 accuracy 50.000
# val part1: loss 2.363386
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 0.837, top-1 accuracy 80.000, top-5 accuracy 96.000
# train part1: loss 0.874002
# val part1: batch 0/59, loss 5.439, top-1 accuracy 10.000, top-5 accuracy 26.000
# val part1: loss 2.350935
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 0.923, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 0.862316
# val part1: batch 0/59, loss 4.356, top-1 accuracy 20.000, top-5 accuracy 46.000
# val part1: loss 2.445387
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 0.681, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 0.815401
# val part1: batch 0/59, loss 3.527, top-1 accuracy 32.000, top-5 accuracy 58.000
# val part1: loss 2.504865
# Checkpoint saved
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 0.621, top-1 accuracy 76.000, top-5 accuracy 100.000
# train part1: loss 0.827840
# val part1: batch 0/59, loss 5.324, top-1 accuracy 10.000, top-5 accuracy 38.000
# val part1: loss 2.476026
# Checkpoint saved
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 0.812, top-1 accuracy 76.000, top-5 accuracy 98.000
# train part1: loss 0.792133
# val part1: batch 0/59, loss 5.533, top-1 accuracy 10.000, top-5 accuracy 42.000
# val part1: loss 2.600064
# Checkpoint saved
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 0.765, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 0.769737
# val part1: batch 0/59, loss 6.123, top-1 accuracy 8.000, top-5 accuracy 30.000
# val part1: loss 2.544250
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 0.909, top-1 accuracy 72.000, top-5 accuracy 94.000
# train part1: loss 0.705327
# val part1: batch 0/59, loss 4.658, top-1 accuracy 14.000, top-5 accuracy 46.000
# val part1: loss 2.588628
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 0.630, top-1 accuracy 84.000, top-5 accuracy 98.000
# train part1: loss 0.718691
# val part1: batch 0/59, loss 4.937, top-1 accuracy 14.000, top-5 accuracy 50.000
# val part1: loss 2.628392
# Checkpoint saved
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 0.751, top-1 accuracy 76.000, top-5 accuracy 98.000
# train part1: loss 0.707350
# val part1: batch 0/59, loss 6.086, top-1 accuracy 8.000, top-5 accuracy 32.000
# val part1: loss 2.723214
# Checkpoint saved
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 0.624, top-1 accuracy 80.000, top-5 accuracy 98.000
# train part1: loss 0.645888
# val part1: batch 0/59, loss 4.379, top-1 accuracy 22.000, top-5 accuracy 54.000
# val part1: loss 2.785266
# Checkpoint saved
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 0.643, top-1 accuracy 80.000, top-5 accuracy 98.000
# train part1: loss 0.638112
# val part1: batch 0/59, loss 4.672, top-1 accuracy 16.000, top-5 accuracy 52.000
# val part1: loss 2.690230
# Checkpoint saved
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 0.458, top-1 accuracy 86.000, top-5 accuracy 100.000
# train part1: loss 0.615343
# val part1: batch 0/59, loss 5.697, top-1 accuracy 12.000, top-5 accuracy 40.000
# val part1: loss 2.807197
# Checkpoint saved
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 0.599, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part1: loss 0.608055
# val part1: batch 0/59, loss 5.092, top-1 accuracy 12.000, top-5 accuracy 46.000
# val part1: loss 2.769045
# Checkpoint saved
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 0.556, top-1 accuracy 86.000, top-5 accuracy 100.000
# train part1: loss 0.547743
# val part1: batch 0/59, loss 4.316, top-1 accuracy 24.000, top-5 accuracy 62.000
# val part1: loss 2.882775
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 0.477, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.520788
# val part1: batch 0/59, loss 5.050, top-1 accuracy 16.000, top-5 accuracy 50.000
# val part1: loss 2.884741
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 0.811, top-1 accuracy 78.000, top-5 accuracy 96.000
# train part1: loss 0.516909
# val part1: batch 0/59, loss 5.235, top-1 accuracy 14.000, top-5 accuracy 50.000
# val part1: loss 2.901748
# Checkpoint saved
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 0.437, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.501564
# val part1: batch 0/59, loss 3.656, top-1 accuracy 28.000, top-5 accuracy 66.000
# val part1: loss 2.971363
# Checkpoint saved
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 0.445, top-1 accuracy 88.000, top-5 accuracy 96.000
# train part1: loss 0.465510
# val part1: batch 0/59, loss 5.070, top-1 accuracy 24.000, top-5 accuracy 50.000
# val part1: loss 2.984059
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 0.486, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.457405
# val part1: batch 0/59, loss 5.713, top-1 accuracy 18.000, top-5 accuracy 48.000
# val part1: loss 2.948285
# Checkpoint saved
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 0.454, top-1 accuracy 86.000, top-5 accuracy 100.000
# train part1: loss 0.428765
# val part1: batch 0/59, loss 4.887, top-1 accuracy 20.000, top-5 accuracy 56.000
# val part1: loss 2.993003
# Checkpoint saved
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 0.453, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.342942
# val part1: batch 0/59, loss 5.108, top-1 accuracy 20.000, top-5 accuracy 58.000
# val part1: loss 2.925307
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 0.191, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.316037
# val part1: batch 0/59, loss 5.064, top-1 accuracy 20.000, top-5 accuracy 58.000
# val part1: loss 2.951937
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 0.304, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.311074
# val part1: batch 0/59, loss 4.977, top-1 accuracy 20.000, top-5 accuracy 58.000
# val part1: loss 2.974059
# Checkpoint saved
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 0.282, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.308218
# val part1: batch 0/59, loss 5.069, top-1 accuracy 22.000, top-5 accuracy 58.000
# val part1: loss 2.973386
# Checkpoint saved
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 0.389, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.307454
# val part1: batch 0/59, loss 4.952, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 2.978776
# Checkpoint saved
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 0.275, top-1 accuracy 98.000, top-5 accuracy 98.000
# train part1: loss 0.303279
# val part1: batch 0/59, loss 4.992, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 2.995079
# Checkpoint saved
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 0.311, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.300887
# val part1: batch 0/59, loss 4.888, top-1 accuracy 22.000, top-5 accuracy 58.000
# val part1: loss 2.988017
# Checkpoint saved
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 0.283, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.299309
# val part1: batch 0/59, loss 5.077, top-1 accuracy 20.000, top-5 accuracy 58.000
# val part1: loss 2.997636
# Checkpoint saved
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 0.152, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part1: loss 0.298455
# val part1: batch 0/59, loss 4.927, top-1 accuracy 22.000, top-5 accuracy 58.000
# val part1: loss 3.011393
# Checkpoint saved
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 0.266, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.294577
# val part1: batch 0/59, loss 5.272, top-1 accuracy 20.000, top-5 accuracy 56.000
# val part1: loss 2.988395
# Checkpoint saved
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 0.234, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part1: loss 0.294848
# val part1: batch 0/59, loss 5.191, top-1 accuracy 20.000, top-5 accuracy 58.000
# val part1: loss 3.000719
# Checkpoint saved
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 0.312, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.291730
# val part1: batch 0/59, loss 5.088, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.003240
# Checkpoint saved
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 0.247, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.291827
# val part1: batch 0/59, loss 4.909, top-1 accuracy 22.000, top-5 accuracy 58.000
# val part1: loss 3.023582
# Checkpoint saved
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 0.281, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.288812
# val part1: batch 0/59, loss 5.211, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.008223
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 0.267, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.288692
# val part1: batch 0/59, loss 5.222, top-1 accuracy 20.000, top-5 accuracy 56.000
# val part1: loss 3.012411
# Checkpoint saved
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 0.284, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.284235
# val part1: batch 0/59, loss 5.121, top-1 accuracy 22.000, top-5 accuracy 58.000
# val part1: loss 3.023161
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 0.170, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part1: loss 0.281412
# val part1: batch 0/59, loss 5.266, top-1 accuracy 20.000, top-5 accuracy 56.000
# val part1: loss 3.030582
# Checkpoint saved
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 0.290, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.283425
# val part1: batch 0/59, loss 5.046, top-1 accuracy 22.000, top-5 accuracy 58.000
# val part1: loss 3.031862
# Checkpoint saved
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 0.291, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.280383
# val part1: batch 0/59, loss 5.412, top-1 accuracy 22.000, top-5 accuracy 54.000
# val part1: loss 3.034105
# Checkpoint saved
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 0.309, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.278740
# val part1: batch 0/59, loss 5.232, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.047845
# Checkpoint saved
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 0.356, top-1 accuracy 92.000, top-5 accuracy 96.000
# train part1: loss 0.279642
# val part1: batch 0/59, loss 4.842, top-1 accuracy 24.000, top-5 accuracy 58.000
# val part1: loss 3.071630
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 0.280, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.279152
# val part1: batch 0/59, loss 5.030, top-1 accuracy 22.000, top-5 accuracy 58.000
# val part1: loss 3.060499
# Checkpoint saved
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 0.248, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.276679
# val part1: batch 0/59, loss 5.352, top-1 accuracy 20.000, top-5 accuracy 54.000
# val part1: loss 3.047701
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 0.342, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.273891
# val part1: batch 0/59, loss 5.456, top-1 accuracy 20.000, top-5 accuracy 56.000
# val part1: loss 3.032385
# Checkpoint saved
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 0.360, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.275818
# val part1: batch 0/59, loss 5.089, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.068092
# Checkpoint saved
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 0.283, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.271710
# val part1: batch 0/59, loss 5.438, top-1 accuracy 20.000, top-5 accuracy 56.000
# val part1: loss 3.054233
# Checkpoint saved
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 0.217, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.270678
# val part1: batch 0/59, loss 5.169, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.072168
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 0.242, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.267446
# val part1: batch 0/59, loss 5.210, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.086009
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 0.259, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.266161
# val part1: batch 0/59, loss 5.164, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.093901
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 0.265, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.266215
# val part1: batch 0/59, loss 5.100, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.079527
# Checkpoint saved
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 0.210, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part1: loss 0.267725
# val part1: batch 0/59, loss 5.108, top-1 accuracy 22.000, top-5 accuracy 58.000
# val part1: loss 3.086220
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 0.209, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part1: loss 0.267118
# val part1: batch 0/59, loss 5.272, top-1 accuracy 22.000, top-5 accuracy 54.000
# val part1: loss 3.102159
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 0.252, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.262333
# val part1: batch 0/59, loss 5.116, top-1 accuracy 24.000, top-5 accuracy 58.000
# val part1: loss 3.092633
# Checkpoint saved
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 0.196, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.259645
# val part1: batch 0/59, loss 5.214, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.092686
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 0.263, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.258536
# val part1: batch 0/59, loss 5.343, top-1 accuracy 22.000, top-5 accuracy 54.000
# val part1: loss 3.101940
# Checkpoint saved
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 0.220, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part1: loss 0.257954
# val part1: batch 0/59, loss 5.315, top-1 accuracy 22.000, top-5 accuracy 54.000
# val part1: loss 3.108174
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 0.215, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.256513
# val part1: batch 0/59, loss 5.355, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.108301
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 0.191, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part1: loss 0.255456
# val part1: batch 0/59, loss 5.054, top-1 accuracy 24.000, top-5 accuracy 56.000
# val part1: loss 3.136129
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 0.285, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.254526
# val part1: batch 0/59, loss 5.424, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.105853
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 0.226, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.253474
# val part1: batch 0/59, loss 5.473, top-1 accuracy 22.000, top-5 accuracy 54.000
# val part1: loss 3.115583
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 0.229, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.252413
# val part1: batch 0/59, loss 5.441, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.115074
# Checkpoint saved
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 0.196, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.251616
# val part1: batch 0/59, loss 5.483, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.119599
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 0.182, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part1: loss 0.251598
# val part1: batch 0/59, loss 5.353, top-1 accuracy 22.000, top-5 accuracy 56.000
# val part1: loss 3.133118
# Checkpoint saved
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 0.239, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.249030
# val part1: batch 0/59, loss 5.632, top-1 accuracy 22.000, top-5 accuracy 54.000
# val part1: loss 3.119477
# Checkpoint saved
# Best top-1 Accuracy = 38.124

# %% [markdown]
# Expect this code to take around 5 minutes on CPU or 3 minutes on GPU. Now you are ready to actually modify the functions we used to train our model. Before you move on, make sure to record the accuracy of your network from Part 0, and report it in your write up.

# %% [markdown]
# ## Part 1: Modifying the Dataloaders and the Simple Network create_datasets

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Now you will modify the create_datasets function from student_code. You will add random left-right mirroring and normalization to the transformations applied to the training dataset. You will also add normalization to the transformations applied to the testing dataset.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now you will modify SimpleNet by adding droppout, batch normalization, and additional convolution/maxpool/relu layers. You should achieve an accuracy of at least **50%**. Make sure your network passes this threshold--it is required for full credit on this section!
#
# You can also use the following two blocks to determine the stucture of your network.

# %%
# create the network model
model = sc.SimpleNet(num_classes=num_classes, rgb=False, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): MaxPool2d(kernel_size=5, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (3): ReLU()
#     (4): Dropout(p=0.5)
#     (5): Conv2d(10, 15, kernel_size=(5, 5), stride=(1, 1), bias=False)
#     (6): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): ReLU()
#     (9): Dropout(p=0.5)
#   )
#   (classifier): Conv2d(15, 15, kernel_size=(6, 6), stride=(1, 1))
# )

# %%
# Use this block to determine the kernel size of the conv2d layer in the classifier
# first, set the kernel size of that conv2d layer to 1, and run this block
# then, use that size of input to the classifier printed by this block to
# go back and update the kernel size of the conv2d layer in the classifier
# Finally, run this block again and verify that the network output size is a scalar
# Don't forget to re-run the block above every time you update the SimpleNet class!
from torch.autograd import Variable
data, _ = train_dataset[0]
s = data.size()
data = Variable(data.view(1, *s))
if use_GPU:
    data = data.cuda()
out = model(data)
print('Network output size is ', out.size())
# Out:
# Network output size is  torch.Size([15])

# %% [markdown]
# Next we will create the loss function and the optimizer. You do not have to modify the custom_part1_trainer in student_code if you use the same loss_function, optimizer, scheduler and parameters (n_epoch, batch_size etc.) as provided in this notebook to hit the required threshold of 50% accuracy. If you changed any of these values, it is important that you modify this function in student_code since we will not be using the notebook you submit to evaluate.

# %%
# Set up the trainer. You can modify custom_part1_trainer in
# student_copy.py if you want to try different learning settings.
custom_part1_trainer = sc.custom_part1_trainer(model)

if custom_part1_trainer is None:
    # Create the loss function.
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Create the optimizer and a learning rate scheduler.
    optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
    # Currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

    params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
    
else:
    if 'loss_function' in custom_part1_trainer:
        loss_function = custom_part1_trainer['loss_function']
    if 'optimizer' in custom_part1_trainer:
        optimizer = custom_part1_trainer['optimizer']
    if 'lr_scheduler' in custom_part1_trainer:
        lr_scheduler = custom_part1_trainer['lr_scheduler']
    if 'params' in custom_part1_trainer:
        params = custom_part1_trainer['params']

# %% [markdown]
# We are ready to train our network! As before, we will start a local server to see the training progress of our network (if you server is already running, you should not start another one). Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part1
# resume_optim: True
# experiment: part1
# val_freq: 1
# checkpoint_file: None
# num_workers: 4
# print_freq: 100
# shuffle: True
# batch_size: 50
# do_val: True
# n_epochs: 100
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 2.678, top-1 accuracy 12.000, top-5 accuracy 50.000
# train part1: loss 2.673910
# val part1: batch 0/59, loss 1.826, top-1 accuracy 36.000, top-5 accuracy 92.000
# val part1: loss 2.735530
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 2.606, top-1 accuracy 20.000, top-5 accuracy 54.000
# train part1: loss 2.466444
# val part1: batch 0/59, loss 2.009, top-1 accuracy 42.000, top-5 accuracy 76.000
# val part1: loss 2.363068
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 2.644, top-1 accuracy 16.000, top-5 accuracy 52.000
# train part1: loss 2.218547
# val part1: batch 0/59, loss 2.471, top-1 accuracy 6.000, top-5 accuracy 60.000
# val part1: loss 2.064172
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 1.986, top-1 accuracy 44.000, top-5 accuracy 74.000
# train part1: loss 2.079924
# val part1: batch 0/59, loss 2.190, top-1 accuracy 28.000, top-5 accuracy 70.000
# val part1: loss 1.938385
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 1.737, top-1 accuracy 44.000, top-5 accuracy 84.000
# train part1: loss 1.965173
# val part1: batch 0/59, loss 2.189, top-1 accuracy 26.000, top-5 accuracy 70.000
# val part1: loss 1.903809
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 1.731, top-1 accuracy 46.000, top-5 accuracy 80.000
# train part1: loss 1.917198
# val part1: batch 0/59, loss 2.379, top-1 accuracy 20.000, top-5 accuracy 66.000
# val part1: loss 1.925415
# Checkpoint saved
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 1.963, top-1 accuracy 38.000, top-5 accuracy 78.000
# train part1: loss 1.850123
# val part1: batch 0/59, loss 1.892, top-1 accuracy 34.000, top-5 accuracy 82.000
# val part1: loss 1.823661
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 1.982, top-1 accuracy 34.000, top-5 accuracy 74.000
# train part1: loss 1.817560
# val part1: batch 0/59, loss 2.261, top-1 accuracy 12.000, top-5 accuracy 76.000
# val part1: loss 1.830660
# Checkpoint saved
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 1.690, top-1 accuracy 40.000, top-5 accuracy 88.000
# train part1: loss 1.800120
# val part1: batch 0/59, loss 1.969, top-1 accuracy 40.000, top-5 accuracy 74.000
# val part1: loss 1.788194
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 1.930, top-1 accuracy 40.000, top-5 accuracy 86.000
# train part1: loss 1.770491
# val part1: batch 0/59, loss 2.089, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.774130
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 1.956, top-1 accuracy 38.000, top-5 accuracy 78.000
# train part1: loss 1.731424
# val part1: batch 0/59, loss 1.938, top-1 accuracy 36.000, top-5 accuracy 82.000
# val part1: loss 1.756060
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 1.710, top-1 accuracy 34.000, top-5 accuracy 90.000
# train part1: loss 1.707959
# val part1: batch 0/59, loss 1.818, top-1 accuracy 32.000, top-5 accuracy 84.000
# val part1: loss 1.737780
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 1.641, top-1 accuracy 34.000, top-5 accuracy 98.000
# train part1: loss 1.692672
# val part1: batch 0/59, loss 2.324, top-1 accuracy 6.000, top-5 accuracy 64.000
# val part1: loss 1.713756
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 1.778, top-1 accuracy 42.000, top-5 accuracy 84.000
# train part1: loss 1.696565
# val part1: batch 0/59, loss 1.753, top-1 accuracy 42.000, top-5 accuracy 88.000
# val part1: loss 1.727413
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 1.574, top-1 accuracy 46.000, top-5 accuracy 92.000
# train part1: loss 1.709674
# val part1: batch 0/59, loss 1.835, top-1 accuracy 38.000, top-5 accuracy 90.000
# val part1: loss 1.751021
# Checkpoint saved
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 1.766, top-1 accuracy 42.000, top-5 accuracy 84.000
# train part1: loss 1.645809
# val part1: batch 0/59, loss 1.964, top-1 accuracy 32.000, top-5 accuracy 82.000
# val part1: loss 1.715840
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 1.556, top-1 accuracy 52.000, top-5 accuracy 88.000
# train part1: loss 1.649216
# val part1: batch 0/59, loss 1.888, top-1 accuracy 32.000, top-5 accuracy 88.000
# val part1: loss 1.720470
# Checkpoint saved
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 1.708, top-1 accuracy 50.000, top-5 accuracy 82.000
# train part1: loss 1.623036
# val part1: batch 0/59, loss 2.056, top-1 accuracy 26.000, top-5 accuracy 76.000
# val part1: loss 1.670474
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 1.545, top-1 accuracy 48.000, top-5 accuracy 84.000
# train part1: loss 1.618084
# val part1: batch 0/59, loss 2.232, top-1 accuracy 16.000, top-5 accuracy 66.000
# val part1: loss 1.659127
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 1.762, top-1 accuracy 46.000, top-5 accuracy 86.000
# train part1: loss 1.650250
# val part1: batch 0/59, loss 1.986, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.677902
# Checkpoint saved
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 1.615, top-1 accuracy 48.000, top-5 accuracy 82.000
# train part1: loss 1.614592
# val part1: batch 0/59, loss 1.900, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.693736
# Checkpoint saved
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 1.709, top-1 accuracy 44.000, top-5 accuracy 82.000
# train part1: loss 1.597953
# val part1: batch 0/59, loss 2.184, top-1 accuracy 20.000, top-5 accuracy 70.000
# val part1: loss 1.680075
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 1.617, top-1 accuracy 52.000, top-5 accuracy 86.000
# train part1: loss 1.601089
# val part1: batch 0/59, loss 1.931, top-1 accuracy 24.000, top-5 accuracy 82.000
# val part1: loss 1.713723
# Checkpoint saved
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 1.572, top-1 accuracy 44.000, top-5 accuracy 88.000
# train part1: loss 1.570346
# val part1: batch 0/59, loss 1.863, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.659670
# Checkpoint saved
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 1.278, top-1 accuracy 60.000, top-5 accuracy 88.000
# train part1: loss 1.538167
# val part1: batch 0/59, loss 1.812, top-1 accuracy 44.000, top-5 accuracy 84.000
# val part1: loss 1.714404
# Checkpoint saved
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 1.370, top-1 accuracy 54.000, top-5 accuracy 92.000
# train part1: loss 1.558867
# val part1: batch 0/59, loss 1.961, top-1 accuracy 28.000, top-5 accuracy 80.000
# val part1: loss 1.667078
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 1.802, top-1 accuracy 46.000, top-5 accuracy 80.000
# train part1: loss 1.554096
# val part1: batch 0/59, loss 2.347, top-1 accuracy 16.000, top-5 accuracy 60.000
# val part1: loss 1.659708
# Checkpoint saved
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 1.459, top-1 accuracy 50.000, top-5 accuracy 96.000
# train part1: loss 1.554465
# val part1: batch 0/59, loss 2.128, top-1 accuracy 30.000, top-5 accuracy 76.000
# val part1: loss 1.611950
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 1.507, top-1 accuracy 58.000, top-5 accuracy 86.000
# train part1: loss 1.537226
# val part1: batch 0/59, loss 2.085, top-1 accuracy 26.000, top-5 accuracy 72.000
# val part1: loss 1.613407
# Checkpoint saved
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 1.492, top-1 accuracy 46.000, top-5 accuracy 94.000
# train part1: loss 1.521732
# val part1: batch 0/59, loss 2.310, top-1 accuracy 12.000, top-5 accuracy 74.000
# val part1: loss 1.632295
# Checkpoint saved
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 1.637, top-1 accuracy 44.000, top-5 accuracy 84.000
# train part1: loss 1.510275
# val part1: batch 0/59, loss 2.250, top-1 accuracy 20.000, top-5 accuracy 66.000
# val part1: loss 1.640027
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 1.552, top-1 accuracy 46.000, top-5 accuracy 84.000
# train part1: loss 1.512509
# val part1: batch 0/59, loss 1.711, top-1 accuracy 48.000, top-5 accuracy 84.000
# val part1: loss 1.637625
# Checkpoint saved
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 1.569, top-1 accuracy 48.000, top-5 accuracy 84.000
# train part1: loss 1.507364
# val part1: batch 0/59, loss 1.869, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.661534
# Checkpoint saved
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 1.645, top-1 accuracy 46.000, top-5 accuracy 88.000
# train part1: loss 1.492655
# val part1: batch 0/59, loss 1.794, top-1 accuracy 36.000, top-5 accuracy 82.000
# val part1: loss 1.634914
# Checkpoint saved
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 1.662, top-1 accuracy 48.000, top-5 accuracy 86.000
# train part1: loss 1.503072
# val part1: batch 0/59, loss 2.039, top-1 accuracy 28.000, top-5 accuracy 76.000
# val part1: loss 1.614998
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 1.299, top-1 accuracy 58.000, top-5 accuracy 94.000
# train part1: loss 1.494332
# val part1: batch 0/59, loss 2.132, top-1 accuracy 20.000, top-5 accuracy 76.000
# val part1: loss 1.637585
# Checkpoint saved
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 1.471, top-1 accuracy 56.000, top-5 accuracy 90.000
# train part1: loss 1.472016
# val part1: batch 0/59, loss 1.981, top-1 accuracy 20.000, top-5 accuracy 76.000
# val part1: loss 1.634885
# Checkpoint saved
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 1.575, top-1 accuracy 46.000, top-5 accuracy 92.000
# train part1: loss 1.494288
# val part1: batch 0/59, loss 2.218, top-1 accuracy 18.000, top-5 accuracy 62.000
# val part1: loss 1.571814
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 1.510, top-1 accuracy 46.000, top-5 accuracy 88.000
# train part1: loss 1.437904
# val part1: batch 0/59, loss 2.221, top-1 accuracy 24.000, top-5 accuracy 72.000
# val part1: loss 1.597990
# Checkpoint saved
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 1.400, top-1 accuracy 48.000, top-5 accuracy 92.000
# train part1: loss 1.448556
# val part1: batch 0/59, loss 2.343, top-1 accuracy 16.000, top-5 accuracy 70.000
# val part1: loss 1.634042
# Checkpoint saved
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 1.393, top-1 accuracy 50.000, top-5 accuracy 86.000
# train part1: loss 1.440689
# val part1: batch 0/59, loss 2.246, top-1 accuracy 14.000, top-5 accuracy 66.000
# val part1: loss 1.589150
# Checkpoint saved
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 1.739, top-1 accuracy 44.000, top-5 accuracy 82.000
# train part1: loss 1.513974
# val part1: batch 0/59, loss 2.202, top-1 accuracy 20.000, top-5 accuracy 74.000
# val part1: loss 1.683550
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 1.447, top-1 accuracy 54.000, top-5 accuracy 86.000
# train part1: loss 1.464047
# val part1: batch 0/59, loss 2.314, top-1 accuracy 10.000, top-5 accuracy 68.000
# val part1: loss 1.610403
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 1.430, top-1 accuracy 54.000, top-5 accuracy 88.000
# train part1: loss 1.449312
# val part1: batch 0/59, loss 2.191, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.643249
# Checkpoint saved
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 1.434, top-1 accuracy 58.000, top-5 accuracy 94.000
# train part1: loss 1.435555
# val part1: batch 0/59, loss 2.167, top-1 accuracy 20.000, top-5 accuracy 72.000
# val part1: loss 1.639552
# Checkpoint saved
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 1.608, top-1 accuracy 62.000, top-5 accuracy 86.000
# train part1: loss 1.448738
# val part1: batch 0/59, loss 2.147, top-1 accuracy 20.000, top-5 accuracy 78.000
# val part1: loss 1.619445
# Checkpoint saved
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 1.326, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.439208
# val part1: batch 0/59, loss 2.024, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.591356
# Checkpoint saved
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 1.347, top-1 accuracy 58.000, top-5 accuracy 90.000
# train part1: loss 1.400218
# val part1: batch 0/59, loss 2.304, top-1 accuracy 10.000, top-5 accuracy 64.000
# val part1: loss 1.568467
# Checkpoint saved
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 1.304, top-1 accuracy 48.000, top-5 accuracy 92.000
# train part1: loss 1.414124
# val part1: batch 0/59, loss 2.377, top-1 accuracy 8.000, top-5 accuracy 72.000
# val part1: loss 1.558791
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 1.342, top-1 accuracy 56.000, top-5 accuracy 88.000
# train part1: loss 1.400613
# val part1: batch 0/59, loss 2.005, top-1 accuracy 32.000, top-5 accuracy 78.000
# val part1: loss 1.638624
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 1.273, top-1 accuracy 56.000, top-5 accuracy 94.000
# train part1: loss 1.421391
# val part1: batch 0/59, loss 2.056, top-1 accuracy 18.000, top-5 accuracy 76.000
# val part1: loss 1.630870
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 1.120, top-1 accuracy 58.000, top-5 accuracy 98.000
# train part1: loss 1.396882
# val part1: batch 0/59, loss 2.124, top-1 accuracy 20.000, top-5 accuracy 76.000
# val part1: loss 1.547816
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 1.897, top-1 accuracy 26.000, top-5 accuracy 82.000
# train part1: loss 1.431834
# val part1: batch 0/59, loss 1.937, top-1 accuracy 32.000, top-5 accuracy 86.000
# val part1: loss 1.593484
# Checkpoint saved
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 1.530, top-1 accuracy 50.000, top-5 accuracy 88.000
# train part1: loss 1.385656
# val part1: batch 0/59, loss 2.310, top-1 accuracy 16.000, top-5 accuracy 64.000
# val part1: loss 1.581521
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 1.606, top-1 accuracy 50.000, top-5 accuracy 90.000
# train part1: loss 1.426772
# val part1: batch 0/59, loss 2.253, top-1 accuracy 10.000, top-5 accuracy 68.000
# val part1: loss 1.576324
# Checkpoint saved
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 1.125, top-1 accuracy 68.000, top-5 accuracy 94.000
# train part1: loss 1.433623
# val part1: batch 0/59, loss 2.119, top-1 accuracy 26.000, top-5 accuracy 72.000
# val part1: loss 1.631165
# Checkpoint saved
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 1.294, top-1 accuracy 52.000, top-5 accuracy 98.000
# train part1: loss 1.394670
# val part1: batch 0/59, loss 2.191, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.572401
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 1.393, top-1 accuracy 58.000, top-5 accuracy 90.000
# train part1: loss 1.418196
# val part1: batch 0/59, loss 2.220, top-1 accuracy 30.000, top-5 accuracy 74.000
# val part1: loss 1.604443
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 1.218, top-1 accuracy 58.000, top-5 accuracy 96.000
# train part1: loss 1.428991
# val part1: batch 0/59, loss 1.933, top-1 accuracy 34.000, top-5 accuracy 80.000
# val part1: loss 1.568627
# Checkpoint saved
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 1.292, top-1 accuracy 62.000, top-5 accuracy 90.000
# train part1: loss 1.363402
# val part1: batch 0/59, loss 2.137, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.542213
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 1.394, top-1 accuracy 62.000, top-5 accuracy 90.000
# train part1: loss 1.336132
# val part1: batch 0/59, loss 2.156, top-1 accuracy 20.000, top-5 accuracy 76.000
# val part1: loss 1.515308
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 1.277, top-1 accuracy 50.000, top-5 accuracy 92.000
# train part1: loss 1.297008
# val part1: batch 0/59, loss 2.151, top-1 accuracy 18.000, top-5 accuracy 74.000
# val part1: loss 1.507522
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 1.197, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.339588
# val part1: batch 0/59, loss 2.122, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.507003
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 1.242, top-1 accuracy 62.000, top-5 accuracy 92.000
# train part1: loss 1.337956
# val part1: batch 0/59, loss 2.077, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.513378
# Checkpoint saved
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 1.429, top-1 accuracy 46.000, top-5 accuracy 86.000
# train part1: loss 1.284295
# val part1: batch 0/59, loss 2.119, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.509077
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 1.321, top-1 accuracy 58.000, top-5 accuracy 88.000
# train part1: loss 1.321703
# val part1: batch 0/59, loss 2.091, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.511371
# Checkpoint saved
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 1.243, top-1 accuracy 58.000, top-5 accuracy 86.000
# train part1: loss 1.314444
# val part1: batch 0/59, loss 2.096, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.499937
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 1.075, top-1 accuracy 62.000, top-5 accuracy 100.000
# train part1: loss 1.291501
# val part1: batch 0/59, loss 2.047, top-1 accuracy 26.000, top-5 accuracy 74.000
# val part1: loss 1.510416
# Checkpoint saved
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 1.136, top-1 accuracy 70.000, top-5 accuracy 94.000
# train part1: loss 1.308333
# val part1: batch 0/59, loss 2.078, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.499291
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 1.197, top-1 accuracy 62.000, top-5 accuracy 96.000
# train part1: loss 1.326894
# val part1: batch 0/59, loss 2.118, top-1 accuracy 22.000, top-5 accuracy 76.000
# val part1: loss 1.511377
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 1.352, top-1 accuracy 58.000, top-5 accuracy 92.000
# train part1: loss 1.325305
# val part1: batch 0/59, loss 2.070, top-1 accuracy 26.000, top-5 accuracy 74.000
# val part1: loss 1.497749
# Checkpoint saved
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 1.580, top-1 accuracy 34.000, top-5 accuracy 92.000
# train part1: loss 1.317197
# val part1: batch 0/59, loss 2.031, top-1 accuracy 28.000, top-5 accuracy 74.000
# val part1: loss 1.501502
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 1.440, top-1 accuracy 44.000, top-5 accuracy 88.000
# train part1: loss 1.303900
# val part1: batch 0/59, loss 2.096, top-1 accuracy 20.000, top-5 accuracy 74.000
# val part1: loss 1.497347
# Checkpoint saved
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 1.475, top-1 accuracy 46.000, top-5 accuracy 90.000
# train part1: loss 1.289020
# val part1: batch 0/59, loss 2.100, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.501453
# Checkpoint saved
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 1.585, top-1 accuracy 48.000, top-5 accuracy 88.000
# train part1: loss 1.330911
# val part1: batch 0/59, loss 2.094, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.503884
# Checkpoint saved
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 1.468, top-1 accuracy 54.000, top-5 accuracy 88.000
# train part1: loss 1.266258
# val part1: batch 0/59, loss 2.086, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.504843
# Checkpoint saved
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 1.362, top-1 accuracy 58.000, top-5 accuracy 88.000
# train part1: loss 1.304496
# val part1: batch 0/59, loss 2.083, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.496495
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 1.334, top-1 accuracy 46.000, top-5 accuracy 92.000
# train part1: loss 1.315800
# val part1: batch 0/59, loss 2.048, top-1 accuracy 28.000, top-5 accuracy 76.000
# val part1: loss 1.500225
# Checkpoint saved
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 1.436, top-1 accuracy 54.000, top-5 accuracy 88.000
# train part1: loss 1.313122
# val part1: batch 0/59, loss 2.103, top-1 accuracy 22.000, top-5 accuracy 76.000
# val part1: loss 1.497331
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 1.412, top-1 accuracy 56.000, top-5 accuracy 94.000
# train part1: loss 1.307045
# val part1: batch 0/59, loss 2.065, top-1 accuracy 26.000, top-5 accuracy 76.000
# val part1: loss 1.493991
# Checkpoint saved
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 1.177, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.292072
# val part1: batch 0/59, loss 2.058, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.491016
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 1.368, top-1 accuracy 58.000, top-5 accuracy 96.000
# train part1: loss 1.312515
# val part1: batch 0/59, loss 2.074, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.499026
# Checkpoint saved
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 1.002, top-1 accuracy 68.000, top-5 accuracy 98.000
# train part1: loss 1.285830
# val part1: batch 0/59, loss 2.070, top-1 accuracy 28.000, top-5 accuracy 78.000
# val part1: loss 1.512045
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 1.243, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.272247
# val part1: batch 0/59, loss 2.078, top-1 accuracy 26.000, top-5 accuracy 74.000
# val part1: loss 1.498977
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 1.259, top-1 accuracy 68.000, top-5 accuracy 94.000
# train part1: loss 1.300858
# val part1: batch 0/59, loss 2.090, top-1 accuracy 26.000, top-5 accuracy 74.000
# val part1: loss 1.495296
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 1.421, top-1 accuracy 56.000, top-5 accuracy 92.000
# train part1: loss 1.264476
# val part1: batch 0/59, loss 2.120, top-1 accuracy 24.000, top-5 accuracy 76.000
# val part1: loss 1.500994
# Checkpoint saved
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 1.121, top-1 accuracy 70.000, top-5 accuracy 96.000
# train part1: loss 1.271868
# val part1: batch 0/59, loss 2.135, top-1 accuracy 22.000, top-5 accuracy 76.000
# val part1: loss 1.494992
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 1.342, top-1 accuracy 44.000, top-5 accuracy 94.000
# train part1: loss 1.330787
# val part1: batch 0/59, loss 2.060, top-1 accuracy 26.000, top-5 accuracy 74.000
# val part1: loss 1.503218
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 1.354, top-1 accuracy 54.000, top-5 accuracy 90.000
# train part1: loss 1.286689
# val part1: batch 0/59, loss 2.105, top-1 accuracy 24.000, top-5 accuracy 76.000
# val part1: loss 1.500778
# Checkpoint saved
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 0.887, top-1 accuracy 70.000, top-5 accuracy 98.000
# train part1: loss 1.315437
# val part1: batch 0/59, loss 2.083, top-1 accuracy 24.000, top-5 accuracy 76.000
# val part1: loss 1.496821
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 1.420, top-1 accuracy 54.000, top-5 accuracy 88.000
# train part1: loss 1.300405
# val part1: batch 0/59, loss 2.071, top-1 accuracy 28.000, top-5 accuracy 76.000
# val part1: loss 1.502659
# Checkpoint saved
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 1.082, top-1 accuracy 66.000, top-5 accuracy 94.000
# train part1: loss 1.270781
# val part1: batch 0/59, loss 2.146, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.508554
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 1.292, top-1 accuracy 66.000, top-5 accuracy 90.000
# train part1: loss 1.281246
# val part1: batch 0/59, loss 2.130, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.489649
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 1.235, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.280071
# val part1: batch 0/59, loss 2.104, top-1 accuracy 24.000, top-5 accuracy 76.000
# val part1: loss 1.500436
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 1.150, top-1 accuracy 64.000, top-5 accuracy 92.000
# train part1: loss 1.292240
# val part1: batch 0/59, loss 2.099, top-1 accuracy 26.000, top-5 accuracy 76.000
# val part1: loss 1.498553
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 1.157, top-1 accuracy 62.000, top-5 accuracy 96.000
# train part1: loss 1.279566
# val part1: batch 0/59, loss 2.019, top-1 accuracy 28.000, top-5 accuracy 74.000
# val part1: loss 1.501158
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 1.226, top-1 accuracy 56.000, top-5 accuracy 90.000
# train part1: loss 1.279682
# val part1: batch 0/59, loss 2.100, top-1 accuracy 24.000, top-5 accuracy 76.000
# val part1: loss 1.488922
# Checkpoint saved
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 1.244, top-1 accuracy 64.000, top-5 accuracy 84.000
# train part1: loss 1.299871
# val part1: batch 0/59, loss 2.022, top-1 accuracy 30.000, top-5 accuracy 76.000
# val part1: loss 1.491519
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 1.313, top-1 accuracy 52.000, top-5 accuracy 98.000
# train part1: loss 1.288521
# val part1: batch 0/59, loss 2.102, top-1 accuracy 26.000, top-5 accuracy 76.000
# val part1: loss 1.499940
# Checkpoint saved
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 1.224, top-1 accuracy 64.000, top-5 accuracy 92.000
# train part1: loss 1.276403
# val part1: batch 0/59, loss 2.112, top-1 accuracy 24.000, top-5 accuracy 76.000
# val part1: loss 1.489885
# Checkpoint saved
# Best top-1 Accuracy = 53.266

# %% [markdown]
# Make sure you get at least 50% accuracy in this section! If you tried different settings than the ones provided to get 50%, you should modify custom_part1_trainer in student code to return a dictionary with your changed settings.

# %% [markdown]
# ## Part 2. Fine-Tuning a Pre-Trained Network

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Training a network from scratch takes a lof of time. Instead of training from scratch, we can take a pre-trained model and fine tune it for our purposes. This is the goal of Part 2--you will train a pre-trained network, and achieve at least 80% accuracy.

# %%
# training parameters
input_size = (224, 224)
RGB = True
base_lr = 1e-3
weight_decay = 5e-4
momentum = 0.9
backprop_depth = 3

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45611589 0.45611589 0.45611589]
# std =
# [0.24786406 0.24786406 0.24786406]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45549639 0.45549639 0.45549639]
# std =
# [0.24698076 0.24698076 0.24698076]

# %% [markdown]
# Following block loads a pretrained AlexNet.

# %%
# Create the network model.
model = alexnet(pretrained=True)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Now, you modify create_part2_model from student code in order to fine-tune AlexNet. As you can see in the docs (https://github.com/pytorch/vision/blob/master/torchvision/models/alexnet.py) and in the model printout above, AlexNet has 2 parts: 'features', which constists of conv layers that extract feature maps from the image, and 'classifier' which consists of FC layers that classify the features. We want to replace the last Linear layer in model.classifier.

# %%
model = sc.create_part2_model(model, num_classes)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=15, bias=True)
#   )
# )

# %% [markdown]
# Next we will create the loss function and the optimizer. Just as with part 1, if you modify any of the setttings to hit the required accuracy, you must modify custom_part2_trainer function to return a dictionary containing your changes.

# %%
# Set up the trainer. You can modify custom_part2_trainer in
# student_copy.py if you want to try different learning settings.
custom_part2_trainer = sc.custom_part2_trainer(model)

if custom_part2_trainer is None:
    # Create the loss function
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Since we do not want to optimize the whole network, we must extract a list of parameters of interest that will be
    # optimized by the optimizer.
    params_to_optimize = []

    # List of modules in the network
    mods = list(model.features.children()) + list(model.classifier.children())

    # Extract parameters from the last `backprop_depth` modules in the network and collect them in
    # the params_to_optimize list.
    for m in mods[::-1][:backprop_depth]:
        params_to_optimize.extend(list(m.parameters()))

    # Construct the optimizer    
    optimizer = optim.SGD(params=params_to_optimize, lr=base_lr, weight_decay=weight_decay, momentum=momentum)

    # Create a scheduler, currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    
    params = {'n_epochs': 4, 'batch_size': 10, 'experiment': 'part2'} 
    
else:
    if 'loss_function' in custom_part2_trainer:
        loss_function = custom_part2_trainer['loss_function']
    if 'optimizer' in custom_part2_trainer:
        optimizer = custom_part2_trainer['optimizer']
    if 'lr_scheduler' in custom_part2_trainer:
        lr_scheduler = custom_part2_trainer['lr_scheduler']
    if 'params' in custom_part2_trainer:
        params = custom_part2_trainer['params']

# %% [markdown]
# We are ready to fine tune our network! Just like before, we will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 2 on the top left bar where is says Environment (only select Part 2, do not check main or Part 1).

# %% [markdown]
# # Train the network!
# trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
# best_prec1 = trainer.train_val()
# print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))

# %%
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params) 
best_prec1 = trainer.train_val() 
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part2
# resume_optim: True
# experiment: part2
# val_freq: 1
# checkpoint_file: None
# num_workers: 4
# print_freq: 100
# shuffle: True
# batch_size: 10
# do_val: True
# n_epochs: 4
# ---------------------------------------
# part2 Epoch 0 / 4
# train part2: batch 0/149, loss 2.786, top-1 accuracy 10.000, top-5 accuracy 40.000
# train part2: batch 100/149, loss 1.153, top-1 accuracy 60.000, top-5 accuracy 100.000
# train part2: loss 0.904719
# val part2: batch 0/298, loss 0.492, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.426, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.331, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.456064
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 1 / 4
# train part2: batch 0/149, loss 0.055, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.227, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: loss 0.396999
# val part2: batch 0/298, loss 0.989, top-1 accuracy 60.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.398, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.449, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.447222
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 2 / 4
# train part2: batch 0/149, loss 0.069, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.116, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: loss 0.247608
# val part2: batch 0/298, loss 0.873, top-1 accuracy 60.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.250, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.412, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: loss 0.414034
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 3 / 4
# train part2: batch 0/149, loss 0.031, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.314, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: loss 0.186468
# val part2: batch 0/298, loss 0.368, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.500, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.548, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.414657
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# Best top-1 Accuracy = 86.399

# %% [markdown]
# Expect this code to take around 10 minutes on CPU or 30 seconds on GPU. You should hit 80% accuracy.
